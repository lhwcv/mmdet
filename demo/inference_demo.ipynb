# %%
from mmdet.apis import init_detector, inference_detector, show_result_pyplot
import mmcv

# %%
config_file = '../configs/cz_head/cz_head_coarse.py'
# download the checkpoint from model zoo and put it in `checkpoints/`
checkpoint_file = '/home/lhw/m2_disk/work_dir/cz_head_coarse_256//latest.pth'

# %%
# build the model from a config file and a checkpoint file
model = init_detector(config_file, checkpoint_file, device='cuda:0')

# %%
# test a single image
img = 'person2.jpg'
result = inference_detector(model, img)

# %%
# show the results
show_result_pyplot(model, img, result,score_thr=0.3, fig_size=(20, 15))

# %%
import random
import os
DIR = '/home/lhw/m2_disk/data/HollyWoodHead/JPEGImages/'
fns = os.listdir(DIR)

# %%
fn = random.sample(fns,1)[0]
fn = os.path.join(DIR,fn)
result = inference_detector(model, fn)
show_result_pyplot(model, fn, result,score_thr=0.5, fig_size=(20, 15))
